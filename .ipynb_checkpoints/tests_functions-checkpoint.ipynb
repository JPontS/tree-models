# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
X, y = iris['data'], iris['target']

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
def entropy(labels):
    """Computes the entropy of a set of labels.
    
    Args:
        labels (list): A list of class labels.
    
    Returns:
        float: The entropy value.
    """
    n_labels = len(labels)
    if n_labels == 0:
        return 0
    
    counts = Counter(labels)  # Count occurrences of each class
    probabilities = np.array(list(counts.values())) / n_labels  # Compute probabilities
  
    return -np.sum(probabilities * np.log2(probabilities))

# %%
entropy(y)
# Out:
# [0.33333333 0.33333333 0.33333333]
# 1.584962500721156

# %%
def segregate(inpute_array, lable):
    """
    This function identifies the indeces of the examples that 
    are identified with a particular lable.
    Returns an array with the indices for a given lable.
    """
    outlist = []
    print(outlist)
    for i in range(len(inpute_array)):
        if inpute_array[i] == lable:
            print(outlist, i)
            outlist = outlist + [i]
    return outlist

# %%
def make_split(feature_values, cut)

# %%
entropy(y)
# Out:
# 0.3333333333333333
# 0.3333333333333333
# 0.3333333333333333
# 3.0

# %% [markdown]
# # Build a cut

# %%
n_features = X.shape[1]

# %%
n_features
# Out:
# 4

# %%
np.linspace(np.min(X[:,0]), np.max(X[:,0]), 20)
# Out:
# array([4.3       , 4.48947368, 4.67894737, 4.86842105, 5.05789474,
#        5.24736842, 5.43684211, 5.62631579, 5.81578947, 6.00526316,
#        6.19473684, 6.38421053, 6.57368421, 6.76315789, 6.95263158,
#        7.14210526, 7.33157895, 7.52105263, 7.71052632, 7.9       ])

# %%
cut = 5
feature = 0
condition = X[:,feature] < cut
node1, node2 = y[condition], y[~condition]

# compute entropies
entropy_parent = entropy(y_parent)
information_gain = entropy_parent - (entropy(node_1)*len(node1) - entropy(node_2)*len(node2))/len(y)

# %%
for feature in X.shape[1]:

# %%
def make_split(array, cut):
    condition = array < cut
    return y[condition], y[~condition]

def best_cut_for_feature(feat_array, y, n_cuts=10):
    
    possible_cuts = np.linspace(np.min(feat_array), np.max(feat_array), n_cuts)
    ls_information_gains = []
    for cut in possible_cuts:
        
        node1, node2 = make_split(feat_array, cut)
        #print(node1, node2)
        
        # compute information gain
        entropy_parent = entropy(y_parent)
        information_gain = entropy_parent - (entropy(node1)*len(node1) + entropy(node2)*len(node2))/len(y)
        #print(entropy_parent, entropy(node1)*len(node1)/len(y), entropy(node2)*len(node2)/len(y))
        
        ls_information_gains.append(information_gain)

    return  np.max(ls_information_gains), possible_cuts[np.argmax(ls_information_gains)]

# %%
best_cut_for_feature(X[:,0], y)
# Out:
# (0.5511234895788772, 5.5)

# %%
y_parent = y
information_matrix = 0
for feature in X.shape[1]:
    possible_cuts = np.linspace(np.min(X[:,feature]), np.max(X[:,feature]), 5, endpoint=False)
    ls_information_gains = []
    for cut in possible_cuts:
        
        node1, node2 = make_split(X[:,feature], cut)
        #print(node1, node2)
        
        # compute information gain
        entropy_parent = entropy(y_parent)
        information_gain = entropy_parent - (entropy(node1)*len(node1) + entropy(node2)*len(node2))/len(y)
        #print(entropy_parent, entropy(node1)*len(node1)/len(y), entropy(node2)*len(node2)/len(y))
        
        ls_information_gains.append(information_gain)
        #print (information_gain)

# %%
np.max(ls_information_gains)
# Out:
# 0.5160405287075729

# %%
entropy(y)*2
# Out:
# 3.169925001442312

# %%
ls_information_gains
# Out:
# [3.1361477929747035,
#  3.0806386897724596,
#  3.0112523107696543,
#  2.9141113801657275,
#  2.692074967356751,
#  2.511670381949458,
#  2.4145294513455307,
#  2.234124865938238,
#  2.0259657289298225,
#  1.9010702467247735,
#  1.8178065919214075,
#  1.6374020065141142,
#  1.4708746969073823,
#  1.332101938901772,
#  1.234961008297845,
#  1.2072064566967229,
#  1.151697353494479,
#  1.137820077693918,
#  1.0684336986911127,
#  1.0684336986911127]

# %%
y_parent = y.copy()
entropy_parent = entropy(y_parent)
# Out:
# [0.33333333 0.33333333 0.33333333]

# %%
make_split(X[:,1], )

# %%
information_gain = entropy_parent - (entropy(node_1)*len(node1) - entropy(node_2)*len(node2))/len(y)
# Out:
# [0.90909091 0.04545455 0.04545455]
# [0.234375  0.3828125 0.3828125]

# %%
information_gain
# Out:
# 2.830847725362361

# %%
entropy(y_pred)
# Out:
# [0, 4, 5, 7, 10, 14, 15, 16, 17, 18, 19, 20, 21, 23, 25, 26, 27, 28, 31, 32, 33, 35, 36, 39, 40, 43, 44, 46, 48, 49, 50, 51, 52, 53, 54, 55, 56, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149]
# 0.8533333333333334
# [1, 2, 3, 6, 8, 9, 11, 12, 13, 22, 24, 29, 30, 34, 37, 38, 41, 42, 45, 47, 57, 106]
# 0.14666666666666667
# []
# 0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 entropy(y_pred)
#
# Cell In[85], line 6, in entropy(y_pred)
# ...

# %%
X[:,0]
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. , 7. , 6.4,
#        6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. , 6.1, 5.6,
#        6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7,
#        6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6, 5.5, 5.5,
#        6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7, 6.3, 5.8, 7.1, 6.3,
#        6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5,
#        7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2,
#        7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. , 6.9, 6.7, 6.9, 5.8,
#        6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])

# %% [markdown]
# # Build Decision Tree

# %%
class Node():
    def __init__(self, feature_index=None, threshold=None, left_node=None, right_node=None, informtation_gain=None, value=None):

        self.feature_index = feature_index
        self.threshold = threshold
        self.left_node = left_node
        self.right_node = right_node
        self.informtation_gain = information_gain

        self.value = value
        
class DecisionTreeClassifier():

    def __init__(self, min_samples_split, max_depth):
        
        self.root = None
        
        self.min_samples_split = min_samples_split
        self.max_depth = max_depth

    def build_tree(self, dataset, y_array, current_depth=0):

        num_samples, num_features = dataset.shape
        
        if num_samples>=self.min_samples_split and current_depth<=self.max_depth:

            best_split = self.get_best_split(dataset, y_array)

            if best_split['information_gain'] > 0:

                #recur left branch
                left_node = self.build_tree(best_split['dataset_left'], best_split['y_left'], current_depth+1)
                
                #recur right branch
                right_node = self.get_best_split(best_split['dataset_right'], best_split['y_right'], current_depth+1) 

                return Node(best_split['feature_index'], best_split['threshold'],
                               left_node, right_node, best_split['information_gain'])

        return Node(value=self.compute_leaf_value(y_array))

    def compute_leaf_value(self, y_array):
        list_y = list(y)
        return max(list_y, key=list_y.count)

    def get_best_split(self, dataset, y_array, n_cuts=10):
    
        best_info_split = {}
        max_information_gain = -float("inf")
        
        for feature_index in range(dataset.shape[1]):
    
            # We run through all the features and all possible thresholds
            feature_values = dataset[:,feature_index] 
            possible_thresnold = np.linspace(np.min(feature_values), np.max(feature_values), n_cuts)
            
            for cut in possible_thresnold:
    
                # Make cut and get features and target datasets for both offspring nodes
                dataset_left, dataset_right, y_left, y_right = self.make_split(dataset, y_array, feature_index, cut)
    
                # Check if childs are not null
                if len(dataset_left)>0 and len(dataset_right)>0:
                   
                    # Compute information gain
                    current_information_gain = self.compute_information_gain(y_array, y_left, y_right)
                    if current_information_gain > max_information_gain:
                        best_info_split['feature_index'] = feature_index
                        best_info_split['threshold'] = cut
                        best_info_split['dataset_left'] = dataset_left
                        best_info_split['dataset_right'] = dataset_right
                        best_info_split['y_left'] = y_left
                        best_info_split['y_right'] = y_right
                        best_info_split['information_gain'] = current_information_gain
                        max_information_gain = current_information_gain
    
        return  best_info_split

    def compute_entropy(self, y):

        #check that y is not empty
        n_labels = np.unique(y)
        if len(n_labels) == 0:
            return 0
    
        entropy = 0
        for lable in np.unique(n_labels):
            prob = len(y[y==lable]) / len(y)
            entropy += -prob*np.log2(prob)
      
        return entropy
    
    def make_split(self, dataset, y, feature_index, threshold):
        condition = dataset[:,feature_index] <= threshold
        return dataset[condition,:], dataset[~condition,:], y[condition],  y[~condition]

    def compute_information_gain(self, y_parent, y_left, y_right):
        entropy_parent = self.compute_entropy(y_parent)
        return entropy_parent - (self.compute_entropy(y_left)*len(y_left) + self.compute_entropy(y_right)*len(y_right))/len(y_parent)

    def fit(self, X, y):
        self.root = self.build_tree(X, y, current_depth=0)
        
    def predict(self, X):
        predictions = [self.make_prediction(row, self.root) for row in X]
        return predictions
        
    def make_predicion(self, x, tree):
        if tree.value != None: return tree.value
        feat_value = x[tree.feature_index]
        if feat_value <= tree.threshold:
            return make_prediction(x, tree.left_node)
        else
            return make_prediction(x, tree.right_node)

# %% [markdown]
# ** Falta fer el fit, el predict i el representar el decision tree. **

# %%
dt = DecisionTreeClassifier(10, 2)

# %%
parent = dt.build_tree(X, y)

# %%
dataset_left, dataset_right, y_left, y_right =  make_split(X, y, 0, 5.5)

# %%
best_split(X, y)
# Out:
# {'feature_index': 2,
#  'threshold': 2.311111111111111,
#  'dataset_left': array([[5.1, 3.5, 1.4, 0.2],
#         [4.9, 3. , 1.4, 0.2],
#         [4.7, 3.2, 1.3, 0.2],
#         [4.6, 3.1, 1.5, 0.2],
#         [5. , 3.6, 1.4, 0.2],
#         [5.4, 3.9, 1.7, 0.4],
#         [4.6, 3.4, 1.4, 0.3],
#         [5. , 3.4, 1.5, 0.2],
#         [4.4, 2.9, 1.4, 0.2],
#         [4.9, 3.1, 1.5, 0.1],
#         [5.4, 3.7, 1.5, 0.2],
#         [4.8, 3.4, 1.6, 0.2],
#         [4.8, 3. , 1.4, 0.1],
#         [4.3, 3. , 1.1, 0.1],
#         [5.8, 4. , 1.2, 0.2],
#         [5.7, 4.4, 1.5, 0.4],
#         [5.4, 3.9, 1.3, 0.4],
#         [5.1, 3.5, 1.4, 0.3],
#         [5.7, 3.8, 1.7, 0.3],
#         [5.1, 3.8, 1.5, 0.3],
#         [5.4, 3.4, 1.7, 0.2],
#         [5.1, 3.7, 1.5, 0.4],
#         [4.6, 3.6, 1. , 0.2],
#         [5.1, 3.3, 1.7, 0.5],
#         [4.8, 3.4, 1.9, 0.2],
#         [5. , 3. , 1.6, 0.2],
#         [5. , 3.4, 1.6, 0.4],
#         [5.2, 3.5, 1.5, 0.2],
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 dataset_left.index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
node = 0
cuts_matrix = np.array()
for feature in range(X.shape[1]):
    print(best_cut_for_feature(X[:,feature], y))
# Out:
# (0.5511234895788772, 5.5)
# (0.28312598916883136, 3.3333333333333335)
# (0.9182958340544894, 2.311111111111111)
# (0.9182958340544894, 0.6333333333333333)

# %%
cut

# %% [markdown]
# # EDA

# %%
import seaborn as sns

# %%
df = pd.concat([pd.DataFrame(X), pd.DataFrame(y)], axis=1)
df.columns = ['feat1', 'feat2', 'feat3', 'feat4', 'y']

# %%
df
# Out:
#      feat1  feat2  feat3  feat4  y
# 0      5.1    3.5    1.4    0.2  0
# 1      4.9    3.0    1.4    0.2  0
# 2      4.7    3.2    1.3    0.2  0
# 3      4.6    3.1    1.5    0.2  0
# 4      5.0    3.6    1.4    0.2  0
# ..     ...    ...    ...    ... ..
# 145    6.7    3.0    5.2    2.3  2
# 146    6.3    2.5    5.0    1.9  2
# 147    6.5    3.0    5.2    2.0  2
# 148    6.2    3.4    5.4    2.3  2
# 149    5.9    3.0    5.1    1.8  2
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df, hue='y')
